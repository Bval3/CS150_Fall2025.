# %% [markdown]
# # Benjamin Valenzuela

# %% [markdown]
# # CS150 - Programming assignment 5

# %% [markdown]
# ## Task 1: Weekend Activities as Sets

# %%
actSat = set()

while True:
    activity = input('Enter an activity from last Saturday ("Done" to stop): ')
    if activity == "Done":
        break
    actSat.add(activity)
    
actSun = set()

while True:
    activity = input('Enter an activity from last Sunday ("Done" to stop): ')
    if activity == "Done":
        break
    actSun.add(activity)

print("\nActivities on Saturday:", actSat)
print("Activities on Sunday:", actSun)

both = actSat & actSun
print("Activities done on both days:", both_days)

at_least_one = actSat | actSun
print("Activities done on at least one day:", at_least_one)

# %% [markdown]
# ## Task 2: Triangle Calculations

# %%
import math

def triangle_solve(leg1, leg2):
    hypotenuse = math.sqrt(leg1**2+ leg2**2)
    perimeter = leg1 + leg2+ hypotenuse
    area = 0.5 * leg1 * leg2
    return (hypotenuse, perimeter, area)

# %% [markdown]
# # Task 3: culator Class

# %%
# Task 3 – Calculator Class

class Calculator:
    def __init__(self):
        self.prev_result = None
        self.total_calculations = 0

    def _store_result(self, value):
        self.prev_result = value
        self.total_calculations += 1
        return value

    def add(self, a, b):
        result = a + b
        return self._store_result(result)

    def subtract(self, a, b):
        result = a - b
        return self._store_result(result)

    def multiply(self, a, b):
        result = a * b
        return self._store_result(result)

    def divide(self, a, b):
        if b == 0:
            raise ValueError("Cannot divide by zero.")
        result = a / b
        return self._store_result(result)

    def power(self, a, b):
        result = a ** b
        return self._store_result(result)

    def info(self):
        print(f"Previous result: {self.prev_result}")
        print(f"Total calculations: {self.total_calculations}")
